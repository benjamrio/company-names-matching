# %%
import pandas as pd

df = pd.read_csv("../data/chiffres-cles-2020.csv", sep=";")
siren_table_path = "data/siren_table.csv"

df.head()
# Out:
# C:\Users\benja\AppData\Local\Temp\ipykernel_14968\1258340011.py:3: DtypeWarning: Columns (1,15,25,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/chiffres-cles-2020.csv", sep=";")
#                                     Dénomination      Siren   Nic  \
# 0                           TA.MI.RO.SA. HOLDING  802504068  15.0
# 1                                         M.T.M.  945451169  29.0
# 2  SOCIETE CAPBRETONNAISE DE DISTRIBUTION SOCADI  987020203  20.0
# 3                              SOCIETE INTERGRAS  997868807  55.0
# 4                              NANTET MENUISERIE   76520279  19.0
#
#                                      Forme Juridique Code APE  \
# 0  Societe a responsabilite limitee a associe unique    0000Z
# 1  Societe a responsabilite limitee a associe unique    4110A
# 2                     Societe par actions simplifiee    4711F
# 3                     Societe par actions simplifiee      NaN
# ...

# %%
df = df.rename({"Dénomination" : "companyName"}, axis=1)

# %%
df[["companyName", "Siren"]].to_csv("../data/siren_table.csv", index=False)
